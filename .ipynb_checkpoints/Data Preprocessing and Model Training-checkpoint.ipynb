# %%
import os
import librosa   #for audio processing
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from pedalboard import Pedalboard
from pedalboard.io import AudioFile
from IPython.display import Audio
from collections import defaultdict
import time
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import StringLookup
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from IPython import display
from jiwer import wer

AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
labels=os.listdir("data/")

# %%
labels
# Out:
# ['increase_volume1.mp3',
#  'increase_volume2.mp3',
#  'next_song1.mp3',
#  'next_song2.mp3',
#  'pause_music1.mp3',
#  'pause_music2.mp3',
#  'play_spotify1.mp3',
#  'play_spotify2.mp3',
#  'processed_1000_increase_volume1.wav',
#  'processed_1000_increase_volume2.wav',
#  'processed_1000_next_song1.wav',
#  'processed_1000_next_song2.wav',
#  'processed_1000_pause_music1.wav',
#  'processed_1000_pause_music2.wav',
#  'processed_1000_play_spotify1.wav',
#  'processed_1000_play_spotify2.wav',
#  'processed_1000_reduce_volume1.wav',
#  'processed_1000_reduce_volume2.wav',
#  'processed_1000_skip_song1.wav',
#  'processed_1000_skip_song2.wav',
#  'processed_1000_stop_music1.wav',
#  'processed_1000_stop_music2.wav',
#  'processed_1001_increase_volume1.wav',
#  'processed_1001_increase_volume2.wav',
#  'processed_1001_next_song1.wav',
#  'processed_1001_next_song2.wav',
#  'processed_1001_pause_music1.wav',
#  'processed_1001_pause_music2.wav',
#  'processed_1001_play_spotify1.wav',
#  'processed_1001_play_spotify2.wav',
#  'processed_1001_reduce_volume1.wav',
#  'processed_1001_reduce_volume2.wav',
#  'processed_1001_skip_song1.wav',
#  'processed_1001_skip_song2.wav',
#  'processed_1001_stop_music1.wav',
#  'processed_1001_stop_music2.wav',
#  'processed_1002_increase_volume1.wav',
#  'processed_1002_increase_volume2.wav',
#  'processed_1002_next_song1.wav',
#  'processed_1002_next_song2.wav',
#  'processed_1002_pause_music1.wav',
#  'processed_1002_pause_music2.wav',
#  'processed_1002_play_spotify1.wav',
#  'processed_1002_play_spotify2.wav',
#  'processed_1002_reduce_volume1.wav',
#  'processed_1002_reduce_volume2.wav',
#  'processed_1002_skip_song1.wav',
#  'processed_1002_skip_song2.wav',
#  'processed_1002_stop_music1.wav',
#  'processed_1002_stop_music2.wav',
#  'processed_1003_increase_volume1.wav',
#  'processed_1003_increase_volume2.wav',
#  'processed_1003_next_song1.wav',
#  'processed_1003_next_song2.wav',
#  'processed_1003_pause_music1.wav',
#  'processed_1003_pause_music2.wav',
#  'processed_1003_play_spotify1.wav',
#  'processed_1003_play_spotify2.wav',
#  'processed_1003_reduce_volume1.wav',
#  'processed_1003_reduce_volume2.wav',
#  'processed_1003_skip_song1.wav',
#  'processed_1003_skip_song2.wav',
#  'processed_1003_stop_music1.wav',
#  'processed_1003_stop_music2.wav',
#  'processed_1004_increase_volume1.wav',
#  'processed_1004_increase_volume2.wav',
#  'processed_1004_next_song1.wav',
#  'processed_1004_next_song2.wav',
#  'processed_1004_pause_music1.wav',
#  'processed_1004_pause_music2.wav',
#  'processed_1004_play_spotify1.wav',
#  'processed_1004_play_spotify2.wav',
#  'processed_1004_reduce_volume1.wav',
#  'processed_1004_reduce_volume2.wav',
#  'processed_1004_skip_song1.wav',
#  'processed_1004_skip_song2.wav',
#  'processed_1004_stop_music1.wav',
#  'processed_1004_stop_music2.wav',
#  'processed_1005_increase_volume1.wav',
#  'processed_1005_increase_volume2.wav',
#  'processed_1005_next_song1.wav',
#  'processed_1005_next_song2.wav',
#  'processed_1005_pause_music1.wav',
#  'processed_1005_pause_music2.wav',
#  'processed_1005_play_spotify1.wav',
#  'processed_1005_play_spotify2.wav',
#  'processed_1005_reduce_volume1.wav',
#  'processed_1005_reduce_volume2.wav',
#  'processed_1005_skip_song1.wav',
#  'processed_1005_skip_song2.wav',
#  'processed_1005_stop_music1.wav',
#  'processed_1005_stop_music2.wav',
#  'processed_1006_increase_volume1.wav',
#  'processed_1006_increase_volume2.wav',
#  'processed_1006_next_song1.wav',
#  'processed_1006_next_song2.wav',
#  'processed_1006_pause_music1.wav',
#  'processed_1006_pause_music2.wav',
#  'processed_1006_play_spotify1.wav',
#  'processed_1006_play_spotify2.wav',
#  'processed_1006_reduce_volume1.wav',
#  'processed_1006_reduce_volume2.wav',
#  'processed_1006_skip_song1.wav',
#  'processed_1006_skip_song2.wav',
#  'processed_1006_stop_music1.wav',
#  'processed_1006_stop_music2.wav',
#  'processed_1007_increase_volume1.wav',
#  'processed_1007_increase_volume2.wav',
#  'processed_1007_next_song1.wav',
#  'processed_1007_next_song2.wav',
#  'processed_1007_pause_music1.wav',
#  'processed_1007_pause_music2.wav',
#  'processed_1007_play_spotify1.wav',
#  'processed_1007_play_spotify2.wav',
#  'processed_1007_reduce_volume1.wav',
#  'processed_1007_reduce_volume2.wav',
#  'processed_1007_skip_song1.wav',
#  'processed_1007_skip_song2.wav',
#  'processed_1007_stop_music1.wav',
#  'processed_1007_stop_music2.wav',
#  'processed_1008_increase_volume1.wav',
#  'processed_1008_increase_volume2.wav',
#  'processed_1008_next_song1.wav',
#  'processed_1008_next_song2.wav',
#  'processed_1008_pause_music1.wav',
#  'processed_1008_pause_music2.wav',
#  'processed_1008_play_spotify1.wav',
#  'processed_1008_play_spotify2.wav',
#  'processed_1008_reduce_volume1.wav',
#  'processed_1008_reduce_volume2.wav',
#  'processed_1008_skip_song1.wav',
#  'processed_1008_skip_song2.wav',
#  'processed_1008_stop_music1.wav',
#  'processed_1008_stop_music2.wav',
#  'processed_1009_increase_volume1.wav',
#  'processed_1009_increase_volume2.wav',
#  'processed_1009_next_song1.wav',
#  'processed_1009_next_song2.wav',
#  'processed_1009_pause_music1.wav',
#  'processed_1009_pause_music2.wav',
#  'processed_1009_play_spotify1.wav',
#  'processed_1009_play_spotify2.wav',
#  'processed_1009_reduce_volume1.wav',
#  'processed_1009_reduce_volume2.wav',
#  'processed_1009_skip_song1.wav',
#  'processed_1009_skip_song2.wav',
#  'processed_1009_stop_music1.wav',
#  'processed_1009_stop_music2.wav',
#  'processed_100_increase_volume1.wav',
#  'processed_100_increase_volume2.wav',
#  'processed_100_next_song1.wav',
#  'processed_100_next_song2.wav',
#  'processed_100_pause_music1.wav',
#  'processed_100_pause_music2.wav',
#  'processed_100_play_spotify1.wav',
#  'processed_100_play_spotify2.wav',
#  'processed_100_reduce_volume1.wav',
#  'processed_100_reduce_volume2.wav',
#  'processed_100_skip_song1.wav',
#  'processed_100_skip_song2.wav',
#  'processed_100_stop_music1.wav',
#  'processed_100_stop_music2.wav',
#  'processed_1010_increase_volume1.wav',
#  'processed_1010_increase_volume2.wav',
#  'processed_1010_next_song1.wav',
#  'processed_1010_next_song2.wav',
#  'processed_1010_pause_music1.wav',
#  'processed_1010_pause_music2.wav',
#  'processed_1010_play_spotify1.wav',
#  'processed_1010_play_spotify2.wav',
#  'processed_1010_reduce_volume1.wav',
#  'processed_1010_reduce_volume2.wav',
#  'processed_1010_skip_song1.wav',
#  'processed_1010_skip_song2.wav',
#  'processed_1010_stop_music1.wav',
#  'processed_1010_stop_music2.wav',
#  'processed_1011_increase_volume1.wav',
#  'processed_1011_increase_volume2.wav',
#  'processed_1011_next_song1.wav',
#  'processed_1011_next_song2.wav',
#  'processed_1011_pause_music1.wav',
#  'processed_1011_pause_music2.wav',
#  'processed_1011_play_spotify1.wav',
#  'processed_1011_play_spotify2.wav',
#  'processed_1011_reduce_volume1.wav',
#  'processed_1011_reduce_volume2.wav',
#  'processed_1011_skip_song1.wav',
#  'processed_1011_skip_song2.wav',
#  'processed_1011_stop_music1.wav',
#  'processed_1011_stop_music2.wav',
#  'processed_1012_increase_volume1.wav',
#  'processed_1012_increase_volume2.wav',
#  'processed_1012_next_song1.wav',
#  'processed_1012_next_song2.wav',
#  'processed_1012_pause_music1.wav',
#  'processed_1012_pause_music2.wav',
#  'processed_1012_play_spotify1.wav',
#  'processed_1012_play_spotify2.wav',
#  'processed_1012_reduce_volume1.wav',
#  'processed_1012_reduce_volume2.wav',
#  'processed_1012_skip_song1.wav',
#  'processed_1012_skip_song2.wav',
#  'processed_1012_stop_music1.wav',
#  'processed_1012_stop_music2.wav',
#  'processed_1013_increase_volume1.wav',
#  'processed_1013_increase_volume2.wav',
#  'processed_1013_next_song1.wav',
#  'processed_1013_next_song2.wav',
#  'processed_1013_pause_music1.wav',
#  'processed_1013_pause_music2.wav',
#  'processed_1013_play_spotify1.wav',
#  'processed_1013_play_spotify2.wav',
#  'processed_1013_reduce_volume1.wav',
#  'processed_1013_reduce_volume2.wav',
#  'processed_1013_skip_song1.wav',
#  'processed_1013_skip_song2.wav',
#  'processed_1013_stop_music1.wav',
#  'processed_1013_stop_music2.wav',
#  'processed_1014_increase_volume1.wav',
#  'processed_1014_increase_volume2.wav',
#  'processed_1014_next_song1.wav',
#  'processed_1014_next_song2.wav',
#  'processed_1014_pause_music1.wav',
#  'processed_1014_pause_music2.wav',
#  'processed_1014_play_spotify1.wav',
#  'processed_1014_play_spotify2.wav',
#  'processed_1014_reduce_volume1.wav',
#  'processed_1014_reduce_volume2.wav',
#  'processed_1014_skip_song1.wav',
#  'processed_1014_skip_song2.wav',
#  'processed_1014_stop_music1.wav',
#  'processed_1014_stop_music2.wav',
#  'processed_1015_increase_volume1.wav',
#  'processed_1015_increase_volume2.wav',
#  'processed_1015_next_song1.wav',
#  'processed_1015_next_song2.wav',
#  'processed_1015_pause_music1.wav',
#  'processed_1015_pause_music2.wav',
#  'processed_1015_play_spotify1.wav',
#  'processed_1015_play_spotify2.wav',
#  'processed_1015_reduce_volume1.wav',
#  'processed_1015_reduce_volume2.wav',
#  'processed_1015_skip_song1.wav',
#  'processed_1015_skip_song2.wav',
#  'processed_1015_stop_music1.wav',
#  'processed_1015_stop_music2.wav',
#  'processed_1016_increase_volume1.wav',
#  'processed_1016_increase_volume2.wav',
#  'processed_1016_next_song1.wav',
#  'processed_1016_next_song2.wav',
#  'processed_1016_pause_music1.wav',
#  'processed_1016_pause_music2.wav',
#  'processed_1016_play_spotify1.wav',
#  'processed_1016_play_spotify2.wav',
#  'processed_1016_reduce_volume1.wav',
#  'processed_1016_reduce_volume2.wav',
#  'processed_1016_skip_song1.wav',
#  'processed_1016_skip_song2.wav',
#  'processed_1016_stop_music1.wav',
#  'processed_1016_stop_music2.wav',
#  'processed_1017_increase_volume1.wav',
#  'processed_1017_increase_volume2.wav',
#  'processed_1017_next_song1.wav',
#  'processed_1017_next_song2.wav',
#  'processed_1017_pause_music1.wav',
#  'processed_1017_pause_music2.wav',
#  'processed_1017_play_spotify1.wav',
#  'processed_1017_play_spotify2.wav',
#  'processed_1017_reduce_volume1.wav',
#  'processed_1017_reduce_volume2.wav',
#  'processed_1017_skip_song1.wav',
#  'processed_1017_skip_song2.wav',
#  'processed_1017_stop_music1.wav',
#  'processed_1017_stop_music2.wav',
#  'processed_1018_increase_volume1.wav',
#  'processed_1018_increase_volume2.wav',
#  'processed_1018_next_song1.wav',
#  'processed_1018_next_song2.wav',
#  'processed_1018_pause_music1.wav',
#  'processed_1018_pause_music2.wav',
#  'processed_1018_play_spotify1.wav',
#  'processed_1018_play_spotify2.wav',
#  'processed_1018_reduce_volume1.wav',
#  'processed_1018_reduce_volume2.wav',
#  'processed_1018_skip_song1.wav',
#  'processed_1018_skip_song2.wav',
#  'processed_1018_stop_music1.wav',
#  'processed_1018_stop_music2.wav',
#  'processed_1019_increase_volume1.wav',
#  'processed_1019_increase_volume2.wav',
#  'processed_1019_next_song1.wav',
#  'processed_1019_next_song2.wav',
#  'processed_1019_pause_music1.wav',
#  'processed_1019_pause_music2.wav',
#  'processed_1019_play_spotify1.wav',
#  'processed_1019_play_spotify2.wav',
#  'processed_1019_reduce_volume1.wav',
#  'processed_1019_reduce_volume2.wav',
#  'processed_1019_skip_song1.wav',
#  'processed_1019_skip_song2.wav',
#  'processed_1019_stop_music1.wav',
#  'processed_1019_stop_music2.wav',
#  'processed_101_increase_volume1.wav',
#  'processed_101_increase_volume2.wav',
#  'processed_101_next_song1.wav',
#  'processed_101_next_song2.wav',
#  'processed_101_pause_music1.wav',
#  'processed_101_pause_music2.wav',
#  'processed_101_play_spotify1.wav',
#  'processed_101_play_spotify2.wav',
#  'processed_101_reduce_volume1.wav',
#  'processed_101_reduce_volume2.wav',
#  'processed_101_skip_song1.wav',
#  'processed_101_skip_song2.wav',
#  'processed_101_stop_music1.wav',
#  'processed_101_stop_music2.wav',
#  'processed_1020_increase_volume1.wav',
#  'processed_1020_increase_volume2.wav',
#  'processed_1020_next_song1.wav',
#  'processed_1020_next_song2.wav',
#  'processed_1020_pause_music1.wav',
#  'processed_1020_pause_music2.wav',
#  'processed_1020_play_spotify1.wav',
#  'processed_1020_play_spotify2.wav',
#  'processed_1020_reduce_volume1.wav',
#  'processed_1020_reduce_volume2.wav',
#  'processed_1020_skip_song1.wav',
#  'processed_1020_skip_song2.wav',
#  'processed_1020_stop_music1.wav',
#  'processed_1020_stop_music2.wav',
#  'processed_1021_increase_volume1.wav',
#  'processed_1021_increase_volume2.wav',
#  'processed_1021_next_song1.wav',
#  'processed_1021_next_song2.wav',
#  'processed_1021_pause_music1.wav',
#  'processed_1021_pause_music2.wav',
#  'processed_1021_play_spotify1.wav',
#  'processed_1021_play_spotify2.wav',
#  'processed_1021_reduce_volume1.wav',
#  'processed_1021_reduce_volume2.wav',
#  'processed_1021_skip_song1.wav',
#  'processed_1021_skip_song2.wav',
#  'processed_1021_stop_music1.wav',
#  'processed_1021_stop_music2.wav',
#  'processed_1022_increase_volume1.wav',
#  'processed_1022_increase_volume2.wav',
#  'processed_1022_next_song1.wav',
#  'processed_1022_next_song2.wav',
#  'processed_1022_pause_music1.wav',
#  'processed_1022_pause_music2.wav',
#  'processed_1022_play_spotify1.wav',
#  'processed_1022_play_spotify2.wav',
#  'processed_1022_reduce_volume1.wav',
#  'processed_1022_reduce_volume2.wav',
#  'processed_1022_skip_song1.wav',
#  'processed_1022_skip_song2.wav',
#  'processed_1022_stop_music1.wav',
#  'processed_1022_stop_music2.wav',
#  'processed_1023_increase_volume1.wav',
#  'processed_1023_increase_volume2.wav',
#  'processed_1023_next_song1.wav',
#  'processed_1023_next_song2.wav',
#  'processed_1023_pause_music1.wav',
#  'processed_1023_pause_music2.wav',
#  'processed_1023_play_spotify1.wav',
#  'processed_1023_play_spotify2.wav',
#  'processed_1023_reduce_volume1.wav',
#  'processed_1023_reduce_volume2.wav',
#  'processed_1023_skip_song1.wav',
#  'processed_1023_skip_song2.wav',
#  'processed_1023_stop_music1.wav',
#  'processed_1023_stop_music2.wav',
#  'processed_1024_increase_volume1.wav',
#  'processed_1024_increase_volume2.wav',
#  'processed_1024_next_song1.wav',
#  'processed_1024_next_song2.wav',
#  'processed_1024_pause_music1.wav',
#  'processed_1024_pause_music2.wav',
#  'processed_1024_play_spotify1.wav',
#  'processed_1024_play_spotify2.wav',
#  'processed_1024_reduce_volume1.wav',
#  'processed_1024_reduce_volume2.wav',
#  'processed_1024_skip_song1.wav',
#  'processed_1024_skip_song2.wav',
#  'processed_1024_stop_music1.wav',
#  'processed_1024_stop_music2.wav',
#  'processed_1025_increase_volume1.wav',
#  'processed_1025_increase_volume2.wav',
#  'processed_1025_next_song1.wav',
#  'processed_1025_next_song2.wav',
#  'processed_1025_pause_music1.wav',
#  'processed_1025_pause_music2.wav',
#  'processed_1025_play_spotify1.wav',
#  'processed_1025_play_spotify2.wav',
#  'processed_1025_reduce_volume1.wav',
#  'processed_1025_reduce_volume2.wav',
#  'processed_1025_skip_song1.wav',
#  'processed_1025_skip_song2.wav',
#  'processed_1025_stop_music1.wav',
#  'processed_1025_stop_music2.wav',
#  'processed_1026_increase_volume1.wav',
#  'processed_1026_increase_volume2.wav',
#  'processed_1026_next_song1.wav',
#  'processed_1026_next_song2.wav',
#  'processed_1026_pause_music1.wav',
#  'processed_1026_pause_music2.wav',
#  'processed_1026_play_spotify1.wav',
#  'processed_1026_play_spotify2.wav',
#  'processed_1026_reduce_volume1.wav',
#  'processed_1026_reduce_volume2.wav',
#  'processed_1026_skip_song1.wav',
#  'processed_1026_skip_song2.wav',
#  'processed_1026_stop_music1.wav',
#  'processed_1026_stop_music2.wav',
#  'processed_1027_increase_volume1.wav',
#  'processed_1027_increase_volume2.wav',
#  'processed_1027_next_song1.wav',
#  'processed_1027_next_song2.wav',
#  'processed_1027_pause_music1.wav',
#  'processed_1027_pause_music2.wav',
#  'processed_1027_play_spotify1.wav',
#  'processed_1027_play_spotify2.wav',
#  'processed_1027_reduce_volume1.wav',
#  'processed_1027_reduce_volume2.wav',
#  'processed_1027_skip_song1.wav',
#  'processed_1027_skip_song2.wav',
#  'processed_1027_stop_music1.wav',
#  'processed_1027_stop_music2.wav',
#  'processed_1028_increase_volume1.wav',
#  'processed_1028_increase_volume2.wav',
#  'processed_1028_next_song1.wav',
#  'processed_1028_next_song2.wav',
#  'processed_1028_pause_music1.wav',
#  'processed_1028_pause_music2.wav',
#  'processed_1028_play_spotify1.wav',
#  'processed_1028_play_spotify2.wav',
#  'processed_1028_reduce_volume1.wav',
#  'processed_1028_reduce_volume2.wav',
#  'processed_1028_skip_song1.wav',
#  'processed_1028_skip_song2.wav',
#  'processed_1028_stop_music1.wav',
#  'processed_1028_stop_music2.wav',
#  'processed_1029_increase_volume1.wav',
#  'processed_1029_increase_volume2.wav',
#  'processed_1029_next_song1.wav',
#  'processed_1029_next_song2.wav',
#  'processed_1029_pause_music1.wav',
#  'processed_1029_pause_music2.wav',
#  'processed_1029_play_spotify1.wav',
#  'processed_1029_play_spotify2.wav',
#  'processed_1029_reduce_volume1.wav',
#  'processed_1029_reduce_volume2.wav',
#  'processed_1029_skip_song1.wav',
#  'processed_1029_skip_song2.wav',
#  'processed_1029_stop_music1.wav',
#  'processed_1029_stop_music2.wav',
#  'processed_102_increase_volume1.wav',
#  'processed_102_increase_volume2.wav',
#  'processed_102_next_song1.wav',
#  'processed_102_next_song2.wav',
#  'processed_102_pause_music1.wav',
#  'processed_102_pause_music2.wav',
#  'processed_102_play_spotify1.wav',
#  'processed_102_play_spotify2.wav',
#  'processed_102_reduce_volume1.wav',
#  'processed_102_reduce_volume2.wav',
#  'processed_102_skip_song1.wav',
#  'processed_102_skip_song2.wav',
#  'processed_102_stop_music1.wav',
#  'processed_102_stop_music2.wav',
#  'processed_1030_increase_volume1.wav',
#  'processed_1030_increase_volume2.wav',
#  'processed_1030_next_song1.wav',
#  'processed_1030_next_song2.wav',
#  'processed_1030_pause_music1.wav',
#  'processed_1030_pause_music2.wav',
#  'processed_1030_play_spotify1.wav',
#  'processed_1030_play_spotify2.wav',
#  'processed_1030_reduce_volume1.wav',
#  'processed_1030_reduce_volume2.wav',
#  'processed_1030_skip_song1.wav',
#  'processed_1030_skip_song2.wav',
#  'processed_1030_stop_music1.wav',
#  'processed_1030_stop_music2.wav',
#  'processed_1031_increase_volume1.wav',
#  'processed_1031_increase_volume2.wav',
#  'processed_1031_next_song1.wav',
#  'processed_1031_next_song2.wav',
#  'processed_1031_pause_music1.wav',
#  'processed_1031_pause_music2.wav',
#  'processed_1031_play_spotify1.wav',
#  'processed_1031_play_spotify2.wav',
#  'processed_1031_reduce_volume1.wav',
#  'processed_1031_reduce_volume2.wav',
#  'processed_1031_skip_song1.wav',
#  'processed_1031_skip_song2.wav',
#  'processed_1031_stop_music1.wav',
#  'processed_1031_stop_music2.wav',
#  'processed_1032_increase_volume1.wav',
#  'processed_1032_increase_volume2.wav',
#  'processed_1032_next_song1.wav',
#  'processed_1032_next_song2.wav',
#  'processed_1032_pause_music1.wav',
#  'processed_1032_pause_music2.wav',
#  'processed_1032_play_spotify1.wav',
#  'processed_1032_play_spotify2.wav',
#  'processed_1032_reduce_volume1.wav',
#  'processed_1032_reduce_volume2.wav',
#  'processed_1032_skip_song1.wav',
#  'processed_1032_skip_song2.wav',
#  'processed_1032_stop_music1.wav',
#  'processed_1032_stop_music2.wav',
#  'processed_1033_increase_volume1.wav',
#  'processed_1033_increase_volume2.wav',
#  'processed_1033_next_song1.wav',
#  'processed_1033_next_song2.wav',
#  'processed_1033_pause_music1.wav',
#  'processed_1033_pause_music2.wav',
#  'processed_1033_play_spotify1.wav',
#  'processed_1033_play_spotify2.wav',
#  'processed_1033_reduce_volume1.wav',
#  'processed_1033_reduce_volume2.wav',
#  'processed_1033_skip_song1.wav',
#  'processed_1033_skip_song2.wav',
#  'processed_1033_stop_music1.wav',
#  'processed_1033_stop_music2.wav',
#  'processed_1034_increase_volume1.wav',
#  'processed_1034_increase_volume2.wav',
#  'processed_1034_next_song1.wav',
#  'processed_1034_next_song2.wav',
#  'processed_1034_pause_music1.wav',
#  'processed_1034_pause_music2.wav',
#  'processed_1034_play_spotify1.wav',
#  'processed_1034_play_spotify2.wav',
#  'processed_1034_reduce_volume1.wav',
#  'processed_1034_reduce_volume2.wav',
#  'processed_1034_skip_song1.wav',
#  'processed_1034_skip_song2.wav',
#  'processed_1034_stop_music1.wav',
#  'processed_1034_stop_music2.wav',
#  'processed_1035_increase_volume1.wav',
#  'processed_1035_increase_volume2.wav',
#  'processed_1035_next_song1.wav',
#  'processed_1035_next_song2.wav',
#  'processed_1035_pause_music1.wav',
#  'processed_1035_pause_music2.wav',
#  'processed_1035_play_spotify1.wav',
#  'processed_1035_play_spotify2.wav',
#  'processed_1035_reduce_volume1.wav',
#  'processed_1035_reduce_volume2.wav',
#  'processed_1035_skip_song1.wav',
#  'processed_1035_skip_song2.wav',
#  'processed_1035_stop_music1.wav',
#  'processed_1035_stop_music2.wav',
#  'processed_1036_increase_volume1.wav',
#  'processed_1036_increase_volume2.wav',
#  'processed_1036_next_song1.wav',
#  'processed_1036_next_song2.wav',
#  'processed_1036_pause_music1.wav',
#  'processed_1036_pause_music2.wav',
#  'processed_1036_play_spotify1.wav',
#  'processed_1036_play_spotify2.wav',
#  'processed_1036_reduce_volume1.wav',
#  'processed_1036_reduce_volume2.wav',
#  'processed_1036_skip_song1.wav',
#  'processed_1036_skip_song2.wav',
#  'processed_1036_stop_music1.wav',
#  'processed_1036_stop_music2.wav',
#  'processed_1037_increase_volume1.wav',
#  'processed_1037_increase_volume2.wav',
#  'processed_1037_next_song1.wav',
#  'processed_1037_next_song2.wav',
#  'processed_1037_pause_music1.wav',
#  'processed_1037_pause_music2.wav',
#  'processed_1037_play_spotify1.wav',
#  'processed_1037_play_spotify2.wav',
#  'processed_1037_reduce_volume1.wav',
#  'processed_1037_reduce_volume2.wav',
#  'processed_1037_skip_song1.wav',
#  'processed_1037_skip_song2.wav',
#  'processed_1037_stop_music1.wav',
#  'processed_1037_stop_music2.wav',
#  'processed_1038_increase_volume1.wav',
#  'processed_1038_increase_volume2.wav',
#  'processed_1038_next_song1.wav',
#  'processed_1038_next_song2.wav',
#  'processed_1038_pause_music1.wav',
#  'processed_1038_pause_music2.wav',
#  'processed_1038_play_spotify1.wav',
#  'processed_1038_play_spotify2.wav',
#  'processed_1038_reduce_volume1.wav',
#  'processed_1038_reduce_volume2.wav',
#  'processed_1038_skip_song1.wav',
#  'processed_1038_skip_song2.wav',
#  'processed_1038_stop_music1.wav',
#  'processed_1038_stop_music2.wav',
#  'processed_1039_increase_volume1.wav',
#  'processed_1039_increase_volume2.wav',
#  'processed_1039_next_song1.wav',
#  'processed_1039_next_song2.wav',
#  'processed_1039_pause_music1.wav',
#  'processed_1039_pause_music2.wav',
#  'processed_1039_play_spotify1.wav',
#  'processed_1039_play_spotify2.wav',
#  'processed_1039_reduce_volume1.wav',
#  'processed_1039_reduce_volume2.wav',
#  'processed_1039_skip_song1.wav',
#  'processed_1039_skip_song2.wav',
#  'processed_1039_stop_music1.wav',
#  'processed_1039_stop_music2.wav',
#  'processed_103_increase_volume1.wav',
#  'processed_103_increase_volume2.wav',
#  'processed_103_next_song1.wav',
#  'processed_103_next_song2.wav',
#  'processed_103_pause_music1.wav',
#  'processed_103_pause_music2.wav',
#  'processed_103_play_spotify1.wav',
#  'processed_103_play_spotify2.wav',
#  'processed_103_reduce_volume1.wav',
#  'processed_103_reduce_volume2.wav',
#  'processed_103_skip_song1.wav',
#  'processed_103_skip_song2.wav',
#  'processed_103_stop_music1.wav',
#  'processed_103_stop_music2.wav',
#  'processed_1040_increase_volume1.wav',
#  'processed_1040_increase_volume2.wav',
#  'processed_1040_next_song1.wav',
#  'processed_1040_next_song2.wav',
#  'processed_1040_pause_music1.wav',
#  'processed_1040_pause_music2.wav',
#  'processed_1040_play_spotify1.wav',
#  'processed_1040_play_spotify2.wav',
#  'processed_1040_reduce_volume1.wav',
#  'processed_1040_reduce_volume2.wav',
#  'processed_1040_skip_song1.wav',
#  'processed_1040_skip_song2.wav',
#  'processed_1040_stop_music1.wav',
#  'processed_1040_stop_music2.wav',
#  'processed_1041_increase_volume1.wav',
#  'processed_1041_increase_volume2.wav',
#  'processed_1041_next_song1.wav',
#  'processed_1041_next_song2.wav',
#  'processed_1041_pause_music1.wav',
#  'processed_1041_pause_music2.wav',
#  'processed_1041_play_spotify1.wav',
#  'processed_1041_play_spotify2.wav',
#  'processed_1041_reduce_volume1.wav',
#  'processed_1041_reduce_volume2.wav',
#  'processed_1041_skip_song1.wav',
#  'processed_1041_skip_song2.wav',
#  'processed_1041_stop_music1.wav',
#  'processed_1041_stop_music2.wav',
#  'processed_1042_increase_volume1.wav',
#  'processed_1042_increase_volume2.wav',
#  'processed_1042_next_song1.wav',
#  'processed_1042_next_song2.wav',
#  'processed_1042_pause_music1.wav',
#  'processed_1042_pause_music2.wav',
#  'processed_1042_play_spotify1.wav',
#  'processed_1042_play_spotify2.wav',
#  'processed_1042_reduce_volume1.wav',
#  'processed_1042_reduce_volume2.wav',
#  'processed_1042_skip_song1.wav',
#  'processed_1042_skip_song2.wav',
#  'processed_1042_stop_music1.wav',
#  'processed_1042_stop_music2.wav',
#  'processed_1043_increase_volume1.wav',
#  'processed_1043_increase_volume2.wav',
#  'processed_1043_next_song1.wav',
#  'processed_1043_next_song2.wav',
#  'processed_1043_pause_music1.wav',
#  'processed_1043_pause_music2.wav',
#  'processed_1043_play_spotify1.wav',
#  'processed_1043_play_spotify2.wav',
#  'processed_1043_reduce_volume1.wav',
#  'processed_1043_reduce_volume2.wav',
#  'processed_1043_skip_song1.wav',
#  'processed_1043_skip_song2.wav',
#  'processed_1043_stop_music1.wav',
#  'processed_1043_stop_music2.wav',
#  'processed_1044_increase_volume1.wav',
#  'processed_1044_increase_volume2.wav',
#  'processed_1044_next_song1.wav',
#  'processed_1044_next_song2.wav',
#  'processed_1044_pause_music1.wav',
#  'processed_1044_pause_music2.wav',
#  'processed_1044_play_spotify1.wav',
#  'processed_1044_play_spotify2.wav',
#  'processed_1044_reduce_volume1.wav',
#  'processed_1044_reduce_volume2.wav',
#  'processed_1044_skip_song1.wav',
#  'processed_1044_skip_song2.wav',
#  'processed_1044_stop_music1.wav',
#  'processed_1044_stop_music2.wav',
#  'processed_1045_increase_volume1.wav',
#  'processed_1045_increase_volume2.wav',
#  'processed_1045_next_song1.wav',
#  'processed_1045_next_song2.wav',
#  'processed_1045_pause_music1.wav',
#  'processed_1045_pause_music2.wav',
#  'processed_1045_play_spotify1.wav',
#  'processed_1045_play_spotify2.wav',
#  'processed_1045_reduce_volume1.wav',
#  'processed_1045_reduce_volume2.wav',
#  'processed_1045_skip_song1.wav',
#  'processed_1045_skip_song2.wav',
#  'processed_1045_stop_music1.wav',
#  'processed_1045_stop_music2.wav',
#  'processed_1046_increase_volume1.wav',
#  'processed_1046_increase_volume2.wav',
#  'processed_1046_next_song1.wav',
#  'processed_1046_next_song2.wav',
#  'processed_1046_pause_music1.wav',
#  'processed_1046_pause_music2.wav',
#  'processed_1046_play_spotify1.wav',
#  'processed_1046_play_spotify2.wav',
#  'processed_1046_reduce_volume1.wav',
#  'processed_1046_reduce_volume2.wav',
#  'processed_1046_skip_song1.wav',
#  'processed_1046_skip_song2.wav',
#  'processed_1046_stop_music1.wav',
#  'processed_1046_stop_music2.wav',
#  'processed_1047_increase_volume1.wav',
#  'processed_1047_increase_volume2.wav',
#  'processed_1047_next_song1.wav',
#  'processed_1047_next_song2.wav',
#  'processed_1047_pause_music1.wav',
#  'processed_1047_pause_music2.wav',
#  'processed_1047_play_spotify1.wav',
#  'processed_1047_play_spotify2.wav',
#  'processed_1047_reduce_volume1.wav',
#  'processed_1047_reduce_volume2.wav',
#  'processed_1047_skip_song1.wav',
#  'processed_1047_skip_song2.wav',
#  'processed_1047_stop_music1.wav',
#  'processed_1047_stop_music2.wav',
#  'processed_1048_increase_volume1.wav',
#  'processed_1048_increase_volume2.wav',
#  'processed_1048_next_song1.wav',
#  'processed_1048_next_song2.wav',
#  'processed_1048_pause_music1.wav',
#  'processed_1048_pause_music2.wav',
#  'processed_1048_play_spotify1.wav',
#  'processed_1048_play_spotify2.wav',
#  'processed_1048_reduce_volume1.wav',
#  'processed_1048_reduce_volume2.wav',
#  'processed_1048_skip_song1.wav',
#  'processed_1048_skip_song2.wav',
#  'processed_1048_stop_music1.wav',
#  'processed_1048_stop_music2.wav',
#  'processed_1049_increase_volume1.wav',
#  'processed_1049_increase_volume2.wav',
#  'processed_1049_next_song1.wav',
#  'processed_1049_next_song2.wav',
#  'processed_1049_pause_music1.wav',
#  'processed_1049_pause_music2.wav',
#  'processed_1049_play_spotify1.wav',
#  'processed_1049_play_spotify2.wav',
#  'processed_1049_reduce_volume1.wav',
#  'processed_1049_reduce_volume2.wav',
#  'processed_1049_skip_song1.wav',
#  'processed_1049_skip_song2.wav',
#  'processed_1049_stop_music1.wav',
#  'processed_1049_stop_music2.wav',
#  'processed_104_increase_volume1.wav',
#  'processed_104_increase_volume2.wav',
#  'processed_104_next_song1.wav',
#  'processed_104_next_song2.wav',
#  'processed_104_pause_music1.wav',
#  'processed_104_pause_music2.wav',
#  'processed_104_play_spotify1.wav',
#  'processed_104_play_spotify2.wav',
#  'processed_104_reduce_volume1.wav',
#  'processed_104_reduce_volume2.wav',
#  'processed_104_skip_song1.wav',
#  'processed_104_skip_song2.wav',
#  'processed_104_stop_music1.wav',
#  'processed_104_stop_music2.wav',
#  'processed_1050_increase_volume1.wav',
#  'processed_1050_increase_volume2.wav',
#  'processed_1050_next_song1.wav',
#  'processed_1050_next_song2.wav',
#  'processed_1050_pause_music1.wav',
#  'processed_1050_pause_music2.wav',
#  'processed_1050_play_spotify1.wav',
#  'processed_1050_play_spotify2.wav',
#  'processed_1050_reduce_volume1.wav',
#  'processed_1050_reduce_volume2.wav',
#  'processed_1050_skip_song1.wav',
#  'processed_1050_skip_song2.wav',
#  'processed_1050_stop_music1.wav',
#  'processed_1050_stop_music2.wav',
#  'processed_1051_increase_volume1.wav',
#  'processed_1051_increase_volume2.wav',
#  'processed_1051_next_song1.wav',
#  'processed_1051_next_song2.wav',
#  'processed_1051_pause_music1.wav',
#  'processed_1051_pause_music2.wav',
#  'processed_1051_play_spotify1.wav',
#  'processed_1051_play_spotify2.wav',
#  'processed_1051_reduce_volume1.wav',
#  'processed_1051_reduce_volume2.wav',
#  'processed_1051_skip_song1.wav',
#  'processed_1051_skip_song2.wav',
#  'processed_1051_stop_music1.wav',
#  'processed_1051_stop_music2.wav',
#  'processed_1052_increase_volume1.wav',
#  'processed_1052_increase_volume2.wav',
#  'processed_1052_next_song1.wav',
#  'processed_1052_next_song2.wav',
#  'processed_1052_pause_music1.wav',
#  'processed_1052_pause_music2.wav',
#  'processed_1052_play_spotify1.wav',
#  'processed_1052_play_spotify2.wav',
#  'processed_1052_reduce_volume1.wav',
#  'processed_1052_reduce_volume2.wav',
#  'processed_1052_skip_song1.wav',
#  'processed_1052_skip_song2.wav',
#  'processed_1052_stop_music1.wav',
#  'processed_1052_stop_music2.wav',
#  'processed_1053_increase_volume1.wav',
#  'processed_1053_increase_volume2.wav',
#  'processed_1053_next_song1.wav',
#  'processed_1053_next_song2.wav',
#  'processed_1053_pause_music1.wav',
#  'processed_1053_pause_music2.wav',
#  'processed_1053_play_spotify1.wav',
#  'processed_1053_play_spotify2.wav',
#  'processed_1053_reduce_volume1.wav',
#  'processed_1053_reduce_volume2.wav',
#  'processed_1053_skip_song1.wav',
#  'processed_1053_skip_song2.wav',
#  'processed_1053_stop_music1.wav',
#  'processed_1053_stop_music2.wav',
#  'processed_1054_increase_volume1.wav',
#  'processed_1054_increase_volume2.wav',
#  'processed_1054_next_song1.wav',
#  'processed_1054_next_song2.wav',
#  'processed_1054_pause_music1.wav',
#  'processed_1054_pause_music2.wav',
#  'processed_1054_play_spotify1.wav',
#  'processed_1054_play_spotify2.wav',
#  'processed_1054_reduce_volume1.wav',
#  'processed_1054_reduce_volume2.wav',
#  'processed_1054_skip_song1.wav',
#  'processed_1054_skip_song2.wav',
#  'processed_1054_stop_music1.wav',
#  'processed_1054_stop_music2.wav',
#  'processed_1055_increase_volume1.wav',
#  'processed_1055_increase_volume2.wav',
#  'processed_1055_next_song1.wav',
#  'processed_1055_next_song2.wav',
#  'processed_1055_pause_music1.wav',
#  'processed_1055_pause_music2.wav',
#  'processed_1055_play_spotify1.wav',
#  'processed_1055_play_spotify2.wav',
#  'processed_1055_reduce_volume1.wav',
#  'processed_1055_reduce_volume2.wav',
#  'processed_1055_skip_song1.wav',
#  'processed_1055_skip_song2.wav',
#  'processed_1055_stop_music1.wav',
#  'processed_1055_stop_music2.wav',
#  'processed_1056_increase_volume1.wav',
#  'processed_1056_increase_volume2.wav',
#  'processed_1056_next_song1.wav',
#  'processed_1056_next_song2.wav',
#  'processed_1056_pause_music1.wav',
#  'processed_1056_pause_music2.wav',
#  'processed_1056_play_spotify1.wav',
#  'processed_1056_play_spotify2.wav',
#  'processed_1056_reduce_volume1.wav',
#  'processed_1056_reduce_volume2.wav',
#  'processed_1056_skip_song1.wav',
#  'processed_1056_skip_song2.wav',
#  'processed_1056_stop_music1.wav',
#  'processed_1056_stop_music2.wav',
#  'processed_1057_increase_volume1.wav',
#  'processed_1057_increase_volume2.wav',
#  'processed_1057_next_song1.wav',
#  'processed_1057_next_song2.wav',
#  'processed_1057_pause_music1.wav',
#  'processed_1057_pause_music2.wav',
#  'processed_1057_play_spotify1.wav',
#  'processed_1057_play_spotify2.wav',
#  'processed_1057_reduce_volume1.wav',
#  'processed_1057_reduce_volume2.wav',
#  'processed_1057_skip_song1.wav',
#  'processed_1057_skip_song2.wav',
#  'processed_1057_stop_music1.wav',
#  'processed_1057_stop_music2.wav',
#  'processed_1058_increase_volume1.wav',
#  'processed_1058_increase_volume2.wav',
#  'processed_1058_next_song1.wav',
#  'processed_1058_next_song2.wav',
#  'processed_1058_pause_music1.wav',
#  'processed_1058_pause_music2.wav',
#  'processed_1058_play_spotify1.wav',
#  'processed_1058_play_spotify2.wav',
#  'processed_1058_reduce_volume1.wav',
#  'processed_1058_reduce_volume2.wav',
#  'processed_1058_skip_song1.wav',
#  'processed_1058_skip_song2.wav',
#  'processed_1058_stop_music1.wav',
#  'processed_1058_stop_music2.wav',
#  'processed_1059_increase_volume1.wav',
#  'processed_1059_increase_volume2.wav',
#  'processed_1059_next_song1.wav',
#  'processed_1059_next_song2.wav',
#  'processed_1059_pause_music1.wav',
#  'processed_1059_pause_music2.wav',
#  'processed_1059_play_spotify1.wav',
#  'processed_1059_play_spotify2.wav',
#  'processed_1059_reduce_volume1.wav',
#  'processed_1059_reduce_volume2.wav',
#  'processed_1059_skip_song1.wav',
#  'processed_1059_skip_song2.wav',
#  'processed_1059_stop_music1.wav',
#  'processed_1059_stop_music2.wav',
#  'processed_105_increase_volume1.wav',
#  'processed_105_increase_volume2.wav',
#  'processed_105_next_song1.wav',
#  'processed_105_next_song2.wav',
#  'processed_105_pause_music1.wav',
#  'processed_105_pause_music2.wav',
#  'processed_105_play_spotify1.wav',
#  'processed_105_play_spotify2.wav',
#  'processed_105_reduce_volume1.wav',
#  'processed_105_reduce_volume2.wav',
#  'processed_105_skip_song1.wav',
#  'processed_105_skip_song2.wav',
#  'processed_105_stop_music1.wav',
#  'processed_105_stop_music2.wav',
#  'processed_1060_increase_volume1.wav',
#  'processed_1060_increase_volume2.wav',
#  'processed_1060_next_song1.wav',
#  'processed_1060_next_song2.wav',
#  'processed_1060_pause_music1.wav',
#  'processed_1060_pause_music2.wav',
#  'processed_1060_play_spotify1.wav',
#  'processed_1060_play_spotify2.wav',
#  'processed_1060_reduce_volume1.wav',
#  'processed_1060_reduce_volume2.wav',
#  'processed_1060_skip_song1.wav',
#  'processed_1060_skip_song2.wav',
#  'processed_1060_stop_music1.wav',
#  'processed_1060_stop_music2.wav',
#  'processed_1061_increase_volume1.wav',
#  'processed_1061_increase_volume2.wav',
#  'processed_1061_next_song1.wav',
#  'processed_1061_next_song2.wav',
#  'processed_1061_pause_music1.wav',
#  'processed_1061_pause_music2.wav',
#  'processed_1061_play_spotify1.wav',
#  'processed_1061_play_spotify2.wav',
#  'processed_1061_reduce_volume1.wav',
#  'processed_1061_reduce_volume2.wav',
#  'processed_1061_skip_song1.wav',
#  'processed_1061_skip_song2.wav',
#  'processed_1061_stop_music1.wav',
#  'processed_1061_stop_music2.wav',
#  'processed_1062_increase_volume1.wav',
#  'processed_1062_increase_volume2.wav',
#  'processed_1062_next_song1.wav',
#  'processed_1062_next_song2.wav',
#  'processed_1062_pause_music1.wav',
#  'processed_1062_pause_music2.wav',
#  'processed_1062_play_spotify1.wav',
#  'processed_1062_play_spotify2.wav',
#  'processed_1062_reduce_volume1.wav',
#  'processed_1062_reduce_volume2.wav',
#  'processed_1062_skip_song1.wav',
#  'processed_1062_skip_song2.wav',
#  'processed_1062_stop_music1.wav',
#  'processed_1062_stop_music2.wav',
#  'processed_1063_increase_volume1.wav',
#  'processed_1063_increase_volume2.wav',
#  'processed_1063_next_song1.wav',
#  'processed_1063_next_song2.wav',
#  'processed_1063_pause_music1.wav',
#  'processed_1063_pause_music2.wav',
#  'processed_1063_play_spotify1.wav',
#  'processed_1063_play_spotify2.wav',
#  'processed_1063_reduce_volume1.wav',
#  'processed_1063_reduce_volume2.wav',
#  'processed_1063_skip_song1.wav',
#  'processed_1063_skip_song2.wav',
#  'processed_1063_stop_music1.wav',
#  'processed_1063_stop_music2.wav',
#  'processed_1064_increase_volume1.wav',
#  'processed_1064_increase_volume2.wav',
#  'processed_1064_next_song1.wav',
#  'processed_1064_next_song2.wav',
#  'processed_1064_pause_music1.wav',
#  'processed_1064_pause_music2.wav',
#  'processed_1064_play_spotify1.wav',
#  'processed_1064_play_spotify2.wav',
#  'processed_1064_reduce_volume1.wav',
#  'processed_1064_reduce_volume2.wav',
#  'processed_1064_skip_song1.wav',
#  'processed_1064_skip_song2.wav',
#  ...]

# %%
audio_types = {
    "increase_volume1.wav": "increase volume",
    "increase_volume2.wav": "increase volume",
    "next_song1.wav": "next song",
    "next_song2.wav": "next song",
    "pause_music1.wav": "pause music",
    "pause_music2.wav": "pause music",
    "play_spotify1.wav": "play spotify",
    "play_spotify2.wav": "play spotify",
    "reduce_volume1.wav": "reduce volume",
    "reduce_volume2.wav": "reduce volume",
    "skip_song1.wav": "skip song",
    "skip_song2.wav": "skip song",
    "stop_music1.wav": "stop music",
    "stop_music2.wav": "stop music",
}

# %%
all_file = []
all_label = []
counter = 0
for label in labels:
    if label[-4:] == ".wav":
        all_file.append(label[:-4])
        if counter % 1000 == 0:
            print(counter)
        for t in audio_types.keys():
            if (t in label):
                all_label.append(audio_types[t]) 
    counter += 1
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000

# %%
metadata_df = pd.DataFrame({"file_name": all_file, "transcription": all_label})

# %%
df_train = metadata_df.sample(frac = 0.7)
rest_part_30 = metadata_df.drop(df_train.index)
df_dev = rest_part_30.sample(frac = 0.66)
df_test = rest_part_30.drop(df_dev.index)

# %%
# The set of characters accepted in the transcription.
characters = [x for x in "abcdefghijklmnopqrstuvwxyz'?! "]
# Mapping characters to integers
char_to_num = keras.layers.StringLookup(vocabulary=characters, oov_token="")
# Mapping integers back to original characters
num_to_char = keras.layers.StringLookup(
    vocabulary=char_to_num.get_vocabulary(), oov_token="", invert=True
)

# %%
# An integer scalar Tensor. The window length in samples.
frame_length = 256
# An integer scalar Tensor. The number of samples to step.
frame_step = 160
# An integer scalar Tensor. The size of the FFT to apply.
# If not provided, uses the smallest power of 2 enclosing frame_length.
fft_length = 384


def encode_single_sample(wav_file, label):
    ###########################################
    ##  Process the Audio
    ##########################################
    # 1. Read wav file
    file = tf.io.read_file('data/' + wav_file + ".wav")
    # 2. Decode the wav file
    audio, _ = tf.audio.decode_wav(file)
    audio = tf.squeeze(audio, axis=-1)
    # 3. Change type to float
    audio = tf.cast(audio, tf.float32)
    # 4. Get the spectrogram
    spectrogram = tf.signal.stft(
        audio, frame_length=frame_length, frame_step=frame_step, fft_length=fft_length
    )
    # 5. We only need the magnitude, which can be derived by applying tf.abs
    spectrogram = tf.abs(spectrogram)
    spectrogram = tf.math.pow(spectrogram, 0.5)
    # 6. normalisation
    means = tf.math.reduce_mean(spectrogram, 1, keepdims=True)
    stddevs = tf.math.reduce_std(spectrogram, 1, keepdims=True)
    spectrogram = (spectrogram - means) / (stddevs + 1e-10)
    ###########################################
    ##  Process the label
    ##########################################
    # 7. Convert label to Lower case
    label = tf.strings.lower(label)
    # 8. Split the label
    label = tf.strings.unicode_split(label, input_encoding="UTF-8")
    # 9. Map the characters in label to numbers
    label = char_to_num(label)
    # 10. Return a dict as our model is expecting two inputs
    return spectrogram, label

# %%
batch_size = 32
# Define the trainig dataset
train_dataset = tf.data.Dataset.from_tensor_slices(
    (list(df_train["file_name"]), list(df_train["transcription"]))
)
train_dataset = (
    train_dataset.map(encode_single_sample, num_parallel_calls=AUTOTUNE)
    .padded_batch(batch_size)
    .prefetch(buffer_size=AUTOTUNE)
)

# Define the develop dataset
develop_dataset = tf.data.Dataset.from_tensor_slices(
    (list(df_dev["file_name"]), list(df_dev["transcription"]))
)
develop_dataset = (
    develop_dataset.map(encode_single_sample, num_parallel_calls=AUTOTUNE)
    .padded_batch(batch_size)
    .prefetch(buffer_size=AUTOTUNE)
)

# Define the test dataset
test_dataset = tf.data.Dataset.from_tensor_slices(
    (list(df_test["file_name"]), list(df_test["transcription"]))
)
test_dataset = (
    test_dataset.map(encode_single_sample, num_parallel_calls=AUTOTUNE)
    .padded_batch(batch_size)
    .prefetch(buffer_size=AUTOTUNE)
)

# %%
fig = plt.figure(figsize=(8, 5))
for batch in train_dataset.take(1):
    spectrogram = batch[0][0].numpy()
    spectrogram = np.array([np.trim_zeros(x) for x in np.transpose(spectrogram)])
    label = batch[1][0]
    # Spectrogram
    label = tf.strings.reduce_join(num_to_char(label)).numpy().decode("utf-8")
    ax = plt.subplot(2, 1, 1)
    ax.imshow(spectrogram, vmax=1)
    ax.set_title(label)
    ax.axis("off")
    # Wav
    file = tf.io.read_file("data/" + list(df_train["file_name"])[0] + ".wav")
    audio, s = tf.audio.decode_wav(file)
    audio = audio.numpy()
    ax = plt.subplot(2, 1, 2)
    plt.plot(audio)
    ax.set_title("Signal Wave")
    ax.set_xlim(0, len(audio))
    display.display(display.Audio(np.transpose(audio), rate=44100))
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def CTCLoss(y_true, y_pred):
    # Compute the training-time loss value
    batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
    input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
    label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

    input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")

    loss = keras.backend.ctc_batch_cost(y_true, y_pred, input_length, label_length)
    return loss

# %%
def build_model(input_dim, output_dim, rnn_layers=5, rnn_units=128):
    """Model similar to DeepSpeech2."""
    # Model's input
    input_spectrogram = layers.Input((None, input_dim), name="input")
    # Expand the dimension to use 2D CNN.
    x = layers.Reshape((-1, input_dim, 1), name="expand_dim")(input_spectrogram)
    # Convolution layer 1
    x = layers.Conv2D(
        filters=32,
        kernel_size=[11, 41],
        strides=[2, 2],
        padding="same",
        use_bias=False,
        name="conv_1",
    )(x)
#     x = layers.BatchNormalization(name="conv_1_bn")(x)
#     x = layers.ReLU(name="conv_1_relu")(x)
    # Convolution layer 2
#     x = layers.Conv2D(
#         filters=32,
#         kernel_size=[11, 21],
#         strides=[1, 2],
#         padding="same",
#         use_bias=False,
#         name="conv_2",
#     )(x)
    x = layers.BatchNormalization(name="conv_2_bn")(x)
    x = layers.ReLU(name="conv_2_relu")(x)
    # Reshape the resulted volume to feed the RNNs layers
    x = layers.Reshape((-1, x.shape[-2] * x.shape[-1]))(x)
#     # RNN layers
#     for i in range(1, rnn_layers + 1):
#         recurrent = layers.GRU(
#             units=rnn_units,
#             activation="tanh",
#             recurrent_activation="sigmoid",
#             use_bias=True,
#             return_sequences=True,
#             reset_after=True,
#             name=f"gru_{i}",
#         )
#         x = layers.Bidirectional(
#             recurrent, name=f"bidirectional_{i}", merge_mode="concat"
#         )(x)
#         if i < rnn_layers:
#             x = layers.Dropout(rate=0.5)(x)
#     # Dense layer
#     x = layers.Dense(units=rnn_units * 2, name="dense_1")(x)
#     x = layers.ReLU(name="dense_1_relu")(x)
#     x = layers.Dropout(rate=0.5)(x)
    # Classification layer
    output = layers.Dense(units=output_dim + 1, activation="softmax")(x)
    # Model
    model = keras.Model(input_spectrogram, output, name="DeepSpeech_2")
    # Optimizer
    opt = keras.optimizers.Adam(learning_rate=1e-4)
    # Compile the model and return
    model.compile(optimizer=opt, loss=CTCLoss)
    return model


# Get the model
model = build_model(
    input_dim=fft_length // 2 + 1,
    output_dim=char_to_num.vocabulary_size(),
    rnn_units=512,
)
model.summary(line_length=110)
# Out:
# Model: "DeepSpeech_2"
# ______________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                                Param #
# ==============================================================================================================
#  input (InputLayer)                              [(None, None, 193)]                         0
#
#  expand_dim (Reshape)                            (None, None, 193, 1)                        0
#
#  conv_1 (Conv2D)                                 (None, None, 97, 32)                        14432
#
#  conv_2_bn (BatchNormalization)                  (None, None, 97, 32)                        128
#
#  conv_2_relu (ReLU)                              (None, None, 97, 32)                        0
#
#  reshape_1 (Reshape)                             (None, None, 3104)                          0
#
#  dense_3 (Dense)                                 (None, None, 32)                            99360
#
# ==============================================================================================================
# Total params: 113,920
# Trainable params: 113,856
# Non-trainable params: 64
# ______________________________________________________________________________________________________________

# %%
# A utility function to decode the output of the network
def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
    # Use greedy search. For complex tasks, you can use beam search
    results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0]
    # Iterate over the results and get back the text
    output_text = []
    for result in results:
        result = tf.strings.reduce_join(num_to_char(result)).numpy().decode("utf-8")
        output_text.append(result)
    return output_text


# A callback class to output a few transcriptions during training
class CallbackEval(keras.callbacks.Callback):
    """Displays a batch of outputs after every epoch."""

    def __init__(self, dataset):
        super().__init__()
        self.dataset = dataset

    def on_epoch_end(self, epoch: int, logs=None):
        predictions = []
        targets = []
        for batch in self.dataset:
            X, y = batch
            batch_predictions = model.predict(X)
            batch_predictions = decode_batch_predictions(batch_predictions)
            predictions.extend(batch_predictions)
            for label in y:
                label = (
                    tf.strings.reduce_join(num_to_char(label)).numpy().decode("utf-8")
                )
                targets.appusend(label)
        wer_score = wer(targets, predictions)
        print("-" * 100)
        print(f"Word Error Rate: {wer_score:.4f}")
        print("-" * 100)
        for i in np.random.randint(0, len(predictions), 2):
            print(f"Target    : {targets[i]}")
            print(f"Prediction: {predictions[i]}")
            print("-" * 100)

# %%
# Define the number of epochs.
epochs = 5
# Callback function to check transcription on the val set.
validation_callback = CallbackEval(develop_dataset)
# Train the model
history = model.fit(
    train_dataset,
    validation_data=develop_dataset,
    epochs=epochs,
    callbacks=[validation_callback],
)
# Out:
# Epoch 1/5
#   2/613 [..............................] - ETA: 47:34 - loss: 1151.3118
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-a1d51d14c1c4> in <module>
#       4 validation_callback = CallbackEval(develop_dataset)
#       5 # Train the model
# ----> 6 history = model.fit(
#       7     train_dataset,
#       8     validation_data=develop_dataset,
#
# ~\AppData\Roaming\Python\Python38\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Roaming\Python\Python38\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.save('models/epoch_1')
# Out:
# INFO:tensorflow:Assets written to: models/epoch_1\assets

# %%
# Let's check results on more validation samples
predictions = []
targets = []
counter = 0
for batch in develop_dataset:
    counter += 1
    print(counter, '/', len(develop_dataset))
    X, y = batch
    batch_predictions = model.predict(X)
    batch_predictions = decode_batch_predictions(batch_predictions)
    predictions.extend(batch_predictions)
    for label in y:
        label = tf.strings.reduce_join(num_to_char(label)).numpy().decode("utf-8")
        targets.append(label)
wer_score = wer(targets, predictions)
print("-" * 100)
print(f"Word Error Rate: {wer_score:.4f}")
print("-" * 100)
for i in np.random.randint(0, len(predictions), 5):
    print(f"Target    : {targets[i]}")
    print(f"Prediction: {predictions[i]}")
    print("-" * 100)
# Out:
# 1 / 174
# 2 / 174
# 3 / 174
# 4 / 174
# 5 / 174
# 6 / 174
# 7 / 174
# 8 / 174
# 9 / 174
# 10 / 174
# 11 / 174
# 12 / 174
# 13 / 174
# 14 / 174
# 15 / 174
# 16 / 174
# 17 / 174
# 18 / 174
# 19 / 174
# 20 / 174
# 21 / 174
# 22 / 174
# 23 / 174
# 24 / 174
# 25 / 174
# 26 / 174
# 27 / 174
# 28 / 174
# 29 / 174
# 30 / 174
# 31 / 174
# 32 / 174
# 33 / 174
# 34 / 174
# 35 / 174
# 36 / 174
# 37 / 174
# 38 / 174
# 39 / 174
# 40 / 174
# 41 / 174
# 42 / 174
# 43 / 174
# 44 / 174
# 45 / 174
# 46 / 174
# 47 / 174
# 48 / 174
# 49 / 174
# 50 / 174
# 51 / 174
# 52 / 174
# 53 / 174
# 54 / 174
# 55 / 174
# 56 / 174
# 57 / 174
# 58 / 174
# 59 / 174
# 60 / 174
# 61 / 174
# 62 / 174
# 63 / 174
# 64 / 174
# 65 / 174
# 66 / 174
# 67 / 174
# 68 / 174
# 69 / 174
# 70 / 174
# 71 / 174
# 72 / 174
# 73 / 174
# 74 / 174
# 75 / 174
# 76 / 174
# 77 / 174
# 78 / 174
# 79 / 174
# 80 / 174
# 81 / 174
# 82 / 174
# 83 / 174
# 84 / 174
# 85 / 174
# 86 / 174
# 87 / 174
# 88 / 174
# 89 / 174
# 90 / 174
# 91 / 174
# 92 / 174
# 93 / 174
# 94 / 174
# 95 / 174
# 96 / 174
# 97 / 174
# 98 / 174
# 99 / 174
# 100 / 174
# 101 / 174
# 102 / 174
# 103 / 174
# 104 / 174
# 105 / 174
# 106 / 174
# 107 / 174
# 108 / 174
# 109 / 174
# 110 / 174
# 111 / 174
# 112 / 174
# 113 / 174
# 114 / 174
# 115 / 174
# 116 / 174
# 117 / 174
# 118 / 174
# 119 / 174
# 120 / 174
# 121 / 174
# 122 / 174
# 123 / 174
# 124 / 174
# 125 / 174
# 126 / 174
# 127 / 174
# 128 / 174
# 129 / 174
# 130 / 174
# 131 / 174
# 132 / 174
# 133 / 174
# 134 / 174
# 135 / 174
# 136 / 174
# 137 / 174
# 138 / 174
# 139 / 174
# 140 / 174
# 141 / 174
# 142 / 174
# 143 / 174
# 144 / 174
# 145 / 174
# 146 / 174
# 147 / 174
# 148 / 174
# 149 / 174
# 150 / 174
# 151 / 174
# 152 / 174
# 153 / 174
# 154 / 174
# 155 / 174
# 156 / 174
# 157 / 174
# 158 / 174
# 159 / 174
# 160 / 174
# 161 / 174
# 162 / 174
# 163 / 174
# 164 / 174
# 165 / 174
# 166 / 174
# 167 / 174
# 168 / 174
# 169 / 174
# 170 / 174
# 171 / 174
# 172 / 174
# 173 / 174
# 174 / 174
# ----------------------------------------------------------------------------------------------------
# Word Error Rate: 0.9894
# ----------------------------------------------------------------------------------------------------
# Target    : increase volume
# Prediction: nrcr srsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsresem
# ----------------------------------------------------------------------------------------------------
# Target    : reduce volume
# Prediction: rsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrseo
# ----------------------------------------------------------------------------------------------------
# Target    : next song
# Prediction: netpa srsog
# ----------------------------------------------------------------------------------------------------
# Target    : reduce volume
# Prediction: rsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrse o
# ----------------------------------------------------------------------------------------------------
# Target    : reduce volume
# Prediction: rsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrsrce oi
# ----------------------------------------------------------------------------------------------------
