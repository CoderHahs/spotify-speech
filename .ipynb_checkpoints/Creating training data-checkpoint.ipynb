# %%
from pedalboard import Pedalboard, Chorus, Reverb, PitchShift, Compressor
from pedalboard.io import AudioFile
from IPython.display import Audio
import time

# %%
audio_file = AudioFile("data/play_spotify1.mp3", 'r')
audio = audio_file.read(audio_file.frames)
samplerate = audio_file.samplerate
    
board = Pedalboard([PitchShift(semitones=15)])

effected = board(audio, samplerate)

new_audio_file = AudioFile('data/processed-play_spotify1.mp3', 'w', samplerate, effected.shape[0])
new_audio_file.write(effected)

# %%
Audio(effected, rate=samplerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
files = [
    "increase_volume1.mp3",
    "increase_volume2.mp3",
    "next_song1.mp3",
    "next_song2.mp3",
    "pause_music1.mp3",
    "pause_music2.mp3",
    "play_spotify1.mp3",
    "play_spotify2.mp3",
    "reduce_volume1.mp3",
    "reduce_volume2.mp3",
    "skip_song1.mp3",
    "skip_song2.mp3",
    "stop_music1.mp3",
    "stop_music2.mp3",
]

# %%
for file in files:
    counter = 1
    start = time.time()
    print("starting", file, start)
    for c in [True, False]:
#         print(c)
        for r in range(5, 54, 5):
            r = r/100
            print(r)
            for p in range(-5, 5, 1):
#                 print(p)
                for d in range(-50, -4, 5):
                    
                    audio_file = AudioFile("data/"+file, 'r')
                    audio = audio_file.read(audio_file.frames)
                    samplerate = audio_file.samplerate
                    
                    if c:
                        board = Pedalboard([Chorus(), Reverb(room_size=r), PitchShift(semitones=p), Compressor(threshold_db=d)])
                    else:
                        board = Pedalboard([Reverb(room_size=r), PitchShift(semitones=p), Compressor(threshold_db=d)])

                    effected = board(audio, samplerate)
                    
                    new_file = "data/processed" + "_" + str(counter) + "_" + file
                        
                    new_audio_file = AudioFile(new_file, 'w', samplerate, effected.shape[0])
                    new_audio_file.write(effected)
                    
                    counter += 1
    print("done", file, time.time()-start)
# Out:
# starting increase_volume1.mp3 1648786896.295444
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done increase_volume1.mp3 444.49231147766113
# starting increase_volume2.mp3 1648787340.7877555
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done increase_volume2.mp3 372.62681794166565
# starting next_song1.mp3 1648787713.4155111
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done next_song1.mp3 326.40140533447266
# starting next_song2.mp3 1648788039.8169165
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done next_song2.mp3 371.0672781467438
# starting pause_music1.mp3 1648788410.8841946
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done pause_music1.mp3 258.5291726589203
# starting pause_music2.mp3 1648788669.4183702
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done pause_music2.mp3 281.22439789772034
# starting play_spotify1.mp3 1648788950.6457705
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done play_spotify1.mp3 239.33243894577026
# starting play_spotify2.mp3 1648789189.9792092
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done play_spotify2.mp3 248.09990763664246
# starting reduce_volume1.mp3 1648789438.0791168
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done reduce_volume1.mp3 372.44899249076843
# starting reduce_volume2.mp3 1648789810.5281093
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done reduce_volume2.mp3 372.0732696056366
# starting skip_song1.mp3 1648790182.6033778
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done skip_song1.mp3 300.604829788208
# starting skip_song2.mp3 1648790483.2092073
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done skip_song2.mp3 412.19498586654663
# starting stop_music1.mp3 1648790895.4041932
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done stop_music1.mp3 394.2209460735321
# starting stop_music2.mp3 1648791289.6251392
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# done stop_music2.mp3 343.15916419029236
